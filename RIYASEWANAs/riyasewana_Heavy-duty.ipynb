# %% [markdown]
# # Heavy-Duty Category

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import time
# from bs4 import BeautifulSoup
# import requests
import pandas as pd

# %%
driver = webdriver.Chrome(executable_path='C:\selenium_browser_drivers\chromedriver.exe')

locations = []
add_dates = []
prices = []
makes = []
models = []
model_years = []
gears = []
fuel_types = []
engine_ccs = []
mileage_km = []

for num in range(1,14):
    if num == 1:
        url = 'https://riyasewana.com/search/heavy-duties'
    else:
        url = 'https://riyasewana.com/search/heavy-duties?page='+str(num)
    print('Started Page no.'+str(num)+'. - ', url)
    
    if num == 13:
        print("PLEASE NOTE - You have reached the last page. If I'm gonna throw an error on this page, ignore me and run the rest of the code as last page may not contain 60 elements. If not, don't worry about what I said..")
    
    time.sleep(2)
    driver.get(url)
    
    driver.implicitly_wait(5)
    
    for i in range(1,61):
        path = "//*[@id='content']/ul/li["+ str(i)+ "]/h2/a"
        driver.find_element_by_xpath(path).click()
#         time.sleep(2)
        try:
            location = driver.find_element_by_xpath("//*[@id='content']/table/tbody/tr[4]/td[2]").text
            locations.append(location)
     
            add_date = driver.find_element_by_xpath("//*[@id='content']/table/tbody/tr[4]/td[4]/time").text
            add_dates.append(add_date)

            price = driver.find_element_by_xpath("//*[@id='content']/table/tbody/tr[5]/td[2]").text
            prices.append(price)

            make = driver.find_element_by_xpath("//*[@id='content']/table/tbody/tr[5]/td[4]").text
            makes.append(make)

            model = driver.find_element_by_xpath("//*[@id='content']/table/tbody/tr[6]/td[2]").text
            models.append(model)

            model_year = driver.find_element_by_xpath("//*[@id='content']/table/tbody/tr[6]/td[4]").text
            model_years.append(model_year)

            gear = driver.find_element_by_xpath("//*[@id='content']/table/tbody/tr[7]/td[2]").text
            gears.append(gear)

            fuel_type = driver.find_element_by_xpath("//*[@id='content']/table/tbody/tr[7]/td[4]").text
            fuel_types.append(fuel_type)

            engine_cc = driver.find_element_by_xpath("//*[@id='content']/table/tbody/tr[8]/td[4]").text
            engine_ccs.append(engine_cc)

            mileage = driver.find_element_by_xpath("//*[@id='content']/table/tbody/tr[9]/td[4]").text
            mileage_km.append(mileage)
            
        except Exception as e:
            print(e)
        driver.back()
#         time.sleep(1)
# Out:
# Started Page no.1. -  https://riyasewana.com/search/heavy-duties
# Started Page no.2. -  https://riyasewana.com/search/heavy-duties?page=2
# Started Page no.3. -  https://riyasewana.com/search/heavy-duties?page=3
# Started Page no.4. -  https://riyasewana.com/search/heavy-duties?page=4
# Started Page no.5. -  https://riyasewana.com/search/heavy-duties?page=5
# Started Page no.6. -  https://riyasewana.com/search/heavy-duties?page=6
# Started Page no.7. -  https://riyasewana.com/search/heavy-duties?page=7
# Started Page no.8. -  https://riyasewana.com/search/heavy-duties?page=8
# Started Page no.9. -  https://riyasewana.com/search/heavy-duties?page=9
# Started Page no.10. -  https://riyasewana.com/search/heavy-duties?page=10
# Started Page no.11. -  https://riyasewana.com/search/heavy-duties?page=11
# Started Page no.12. -  https://riyasewana.com/search/heavy-duties?page=12
# Started Page no.13. -  https://riyasewana.com/search/heavy-duties?page=13
# ...

# %%
df = pd.DataFrame({'location':locations, 'add_date':add_dates, 'price':prices, 'make':makes, 'model':models,
                  'model_year':model_years, 'gear':gears, 'fuel_type':fuel_types, 
                   'engine_cc':engine_ccs, 'mileage_km':mileage_km})

# %%
df.head()
# Out:
#    location              add_date          price     make     model  \
# 0  Tangalle   2020 Oct 18 8:57 am  Rs. 3,700,000      JCB        12
# 1   Negombo   2020 Oct 18 7:48 am    Rs. 850,000  Kobelco     Pw307
# 2   Negombo   2020 Oct 18 7:41 am  Rs. 1,050,000      CAT  428 4 Wd
# 3    Chilaw   2020 Oct 18 6:46 am     Negotiable    Other  Sumo 68G
# 4     Dompe  2020 Oct 17 10:56 pm  Rs. 1,850,000  Komatsu      PC50
#
#   model_year       gear fuel_type engine_cc mileage_km
# 0       2000     Manual    Diesel      2999       5688
# 1       2018  Automatic    Diesel      3000       1000
# 2       1994  Automatic    Diesel      3500      10000
# 3       2019  Automatic    Diesel      2500          0
# 4       2019  Automatic    Diesel      3000       3300

# %%
df.shape
# Out:
# (20, 10)

# %%
# Save the file
df.to_csv('heavy.csv', encoding='utf-8', index=False)
