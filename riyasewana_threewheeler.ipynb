# %% [markdown]
# # Tuktuk Category

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import time
import pandas as pd

# %%
driver = webdriver.Chrome(executable_path='C:\selenium_browser_drivers\chromedriver.exe')


makes = []
models = []
model_years = []
gears = []
fuel_types = []
engine_ccs = []
mileage_km = []
prices = []

for num in range(2,17):

    url = 'https://riyasewana.com/search/three-wheels/2015-2020?page='+str(num)
    print('Started Page no.'+str(num)+'. - ', url)
    time.sleep(2)
    driver.get(url)
 
    
    for i in range(1,61):
        path = "//*[@id='content']/ul/li["+ str(i)+ "]/h2/a"
        driver.find_element_by_xpath(path).click()
#         time.sleep(2)
        try:
        
            make = driver.find_element_by_xpath("//*[@id='content']/table/tbody/tr[5]/td[4]").text
            makes.append(make)

            model = driver.find_element_by_xpath("//*[@id='content']/table/tbody/tr[6]/td[2]").text
            models.append(model)

            model_year = driver.find_element_by_xpath("//*[@id='content']/table/tbody/tr[6]/td[4]").text
            model_years.append(model_year)

            gear = driver.find_element_by_xpath("//*[@id='content']/table/tbody/tr[7]/td[2]").text
            gears.append(gear)

            fuel_type = driver.find_element_by_xpath("//*[@id='content']/table/tbody/tr[7]/td[4]").text
            fuel_types.append(fuel_type)

            engine_cc = driver.find_element_by_xpath("//*[@id='content']/table/tbody/tr[8]/td[4]").text
            engine_ccs.append(engine_cc)

            mileage = driver.find_element_by_xpath("//*[@id='content']/table/tbody/tr[9]/td[4]").text
            mileage_km.append(mileage)
            
            price = driver.find_element_by_xpath("//*[@id='content']/table/tbody/tr[5]/td[2]").text
            prices.append(price)

            
        except Exception as e:
            print(e)
        driver.back()
#         time.sleep(1)
# Out:
# Started Page no.2. -  https://riyasewana.com/search/three-wheels/2015-2020?page=2
# ---------------------------------------------------------------------------
# WebDriverException                        Traceback (most recent call last)
# <ipython-input-2-36454bbe2f78> in <module>
#      21     for i in range(1,61):
#      22         path = "//*[@id='content']/ul/li["+ str(i)+ "]/h2/a"
# ---> 23         driver.find_element_by_xpath(path).click()
#      24 #         time.sleep(2)
#      25         try:
#
# c:\users\hp\appdata\local\programs\python\python37-32\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element_by_xpath(self, xpath)
#     392             element = driver.find_element_by_xpath('//div/td[1]')
#     393         """
# --> 394         return self.find_element(by=By.XPATH, value=xpath)
#     395
#     396     def find_elements_by_xpath(self, xpath):
#
# c:\users\hp\appdata\local\programs\python\python37-32\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element(self, by, value)
#     976         return self.execute(Command.FIND_ELEMENT, {
#     977             'using': by,
# --> 978             'value': value})['value']
#     979
#     980     def find_elements(self, by=By.ID, value=None):
#
# c:\users\hp\appdata\local\programs\python\python37-32\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
# --> 321             self.error_handler.check_response(response)
#     322             response['value'] = self._unwrap_value(
#     323                 response.get('value', None))
#
# c:\users\hp\appdata\local\programs\python\python37-32\lib\site-packages\selenium\webdriver\remote\errorhandler.py in check_response(self, response)
#     240                 alert_text = value['alert'].get('text')
#     241             raise exception_class(message, screen, stacktrace, alert_text)
# --> 242         raise exception_class(message, screen, stacktrace)
#     243
#     244     def _value_or_default(self, obj, key, default):
#
# WebDriverException: Message: chrome not reachable
#   (Session info: chrome=86.0.4240.75)

# %%
df = pd.DataFrame({'make':makes, 'model':models,
                  'model_year':model_years, 'gear':gears, 'fuel_type':fuel_types, 
                   'engine_cc':engine_ccs, 'mileage_km':mileage_km,'price':prices})

# %%
# Save the file
df.to_csv('threewheeler.csv', encoding='utf-8', index=False)
